# %%
import pandas as pd
import numpy as np
ver = 8
file1 = f"C:/Users/alelen/Documents/Export Data/All_points_{ver}.txt"
path = "C:/Users/alelen/Documents/Export Data/"
fields = ["Collection"]
# df = pd.read_csv(file1, skiprows=5, delimiter=",", on_bad_lines="skip", usecols=fields, skip_blank_lines=True)
# df = pd.read_csv(file1, skiprows=5, sep=", ", on_bad_lines="skip", skip_blank_lines=True)
df = pd.read_csv(file1, skiprows=6, sep=",", header=None, on_bad_lines="skip", skip_blank_lines=True, engine="python")

df.rename(columns={0:"Collection", 1:"Group", 2:"Point", 3:"X", 4:"Y", 5:"Z", 6:"Planar offset", 7:"Radial offset",
                   16:"[U-x]", 17:"[U-y]", 18:"[U-z]", 19:"[U-mag]",
                   20:"Timestamp", 22:"Last Face", 23:"Tracker", 24:"Reflector", 25:"Target",
                   26:"RMS Error", 27:"Temperature", 28:"Pressure", 29:"Humidity",
                   30:"Mode", 31:"Status", 32:"Type measurement", 
                   34:"Level compensation 1", 35:"Level compensation 2", 36:"Level compensation 3",
                   37:"[Var(x)]", 38:"[CoVar(xy)]", 39:"[CoVar(xz)]", 40:"[CoVar(xy)]", 41:"[Var(y)]", 42:"[CoVar(yz)]", 
                   43:"[CoVar(xz)]", 44:"[CoVar(yz)]", 45:"[Var(z)]"},inplace=True)

#df = pd.read_table(file1, skiprows=6, sep=",  ", header=None, on_bad_lines="skip", skip_blank_lines=True, engine="python")

#x = df.to_markdown(); print(x)
# df.to_csv(path+f"All_points_cleaned{ver}.txt")

df.tail(1)
df['Temperature'] = df['Temperature'].str.removeprefix('  Weather:T=',)
df['Pressure'] = df['Pressure'].str.lstrip('  P=',)
df['Humidity'] = df['Humidity'].str.lstrip('  H=',)
df['Humidity'] = df['Humidity'].str.rstrip('%',)
# pd.to_numeric(df["Humidity"])

def celsius(fahrenheit): return round(5*(fahrenheit-32)/9,1)

for i,val in enumerate(df['Temperature']):
    if(val[-1]=='F'):
        T = celsius(float(val.split('F')[0]))
        df['Temperature'].iloc[i] = f'{T}C'

def mPa(inHg): return round(inHg*33.863889532610884,1)

for i,val in enumerate(df["Pressure"]):
    if(val[-1] == 'g'):
        P = mPa(float(val.split('inHg')[0]))
        df['Pressure'].iloc[i] = f'{P}hPA(mbar)'

df[['Temperature', 'Pressure', 'Humidity']]
df['Temperature'].str.rstrip('C')
# x = df.to_markdown(); print(x)

df['Temperature'] = df['Temperature'].str.rstrip('C')
df['Pressure'] = df['Pressure'].str.rstrip('hPA(mbar)')
df['Temperature'] = pd.to_numeric(df['Temperature'])
df['Pressure'] = pd.to_numeric(df['Pressure'])
df['Humidity'] = pd.to_numeric(df['Humidity'])

df.to_csv(path+f"All_points_cleaned{ver}.txt")

df[['[U-x]', '[U-y]', '[U-z]', '[U-mag]']].sort_values(by='[U-mag]')
df[['Temperature', 'Pressure', 'Humidity']].sort_values(by='Temperature')


df['Point'].str.strip().to_clipboard()
df['Point'] = df['Point'].str.replace("  ", "")



df['Group'] = df['Group'].str.replace("  ", "")
df['Group'].unique()
st = {}
for i in df['Group'].unique():
    st[i]=[0,0,0]
st
# Out:
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'].iloc[i] = f'{T}C'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# C:\Users\alelen\AppData\Local\Temp\ipykernel_27064\1665576004.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pressure'].iloc[i] = f'{P}hPA(mbar)'
# {'ST001': [0, 0, 0],
#  'ST002': [0, 0, 0],
#  'ST003': [0, 0, 0],
#  'ST004': [0, 0, 0],
#  'ST005': [0, 0, 0],
#  'ST006': [0, 0, 0],
#  'ST007': [0, 0, 0],
#  'ST008': [0, 0, 0],
#  'ST009': [0, 0, 0],
#  'ST010': [0, 0, 0],
#  'ST011': [0, 0, 0],
#  'ST012': [0, 0, 0],
#  'ST013': [0, 0, 0],
#  'ST014': [0, 0, 0],
#  'ST015': [0, 0, 0],
#  'ST016': [0, 0, 0],
#  'ST017': [0, 0, 0],
#  'ST018': [0, 0, 0],
#  'ST019': [0, 0, 0],
#  'ST020': [0, 0, 0],
#  'ST021': [0, 0, 0],
#  'ST022': [0, 0, 0],
#  'ST023': [0, 0, 0],
#  'ST024': [0, 0, 0],
#  'ST025': [0, 0, 0],
#  'ST026': [0, 0, 0],
#  'ST027': [0, 0, 0],
#  'ST028': [0, 0, 0],
#  'ST029': [0, 0, 0],
#  'ST91': [0, 0, 0],
#  'ST87': [0, 0, 0],
#  'ST88': [0, 0, 0],
#  'ST89': [0, 0, 0],
#  'ST90': [0, 0, 0],
#  'ST50': [0, 0, 0],
#  'ST51': [0, 0, 0],
#  'ST52': [0, 0, 0],
#  'ST53': [0, 0, 0],
#  'ST54': [0, 0, 0],
#  'ST55': [0, 0, 0],
#  'ST56': [0, 0, 0],
#  'ST57': [0, 0, 0],
#  'ST58': [0, 0, 0],
#  'ST59': [0, 0, 0],
#  'ST60': [0, 0, 0],
#  'ST61': [0, 0, 0],
#  'ST62': [0, 0, 0],
#  'ST63': [0, 0, 0],
#  'ST64': [0, 0, 0],
#  'ST65': [0, 0, 0],
#  'ST66': [0, 0, 0],
#  'ST67': [0, 0, 0],
#  'ST68': [0, 0, 0],
#  'ST69': [0, 0, 0],
#  'ST70': [0, 0, 0],
#  'ST71': [0, 0, 0],
#  'ST72': [0, 0, 0],
#  'ST73': [0, 0, 0],
#  'ST74': [0, 0, 0],
#  'ST75': [0, 0, 0],
#  'ST76': [0, 0, 0],
#  'ST77': [0, 0, 0],
#  'ST78': [0, 0, 0],
#  'ST79': [0, 0, 0],
#  'ST80': [0, 0, 0],
#  'ST81': [0, 0, 0],
#  'ST82': [0, 0, 0],
#  'ST83': [0, 0, 0],
#  'ST84': [0, 0, 0],
#  'ST85 OBS! PROBLEMATIC': [0, 0, 0],
#  'ST86': [0, 0, 0],
#  'ST100': [0, 0, 0],
#  'ST101': [0, 0, 0],
#  'ST102': [0, 0, 0],
#  'ST103': [0, 0, 0],
#  'ST030': [0, 0, 0],
#  'ST031': [0, 0, 0],
#  'ST032': [0, 0, 0],
#  'ST033': [0, 0, 0],
#  'ST034': [0, 0, 0],
#  'ST035': [0, 0, 0],
#  'ST036': [0, 0, 0],
#  'ST037': [0, 0, 0],
#  'ST038': [0, 0, 0],
#  'ST039': [0, 0, 0],
#  'ST040': [0, 0, 0],
#  'ST041': [0, 0, 0],
#  'ST042': [0, 0, 0],
#  'ST043': [0, 0, 0],
#  'ST044': [0, 0, 0],
#  'ST045': [0, 0, 0],
#  'ST046': [0, 0, 0],
#  'ST047': [0, 0, 0],
#  'ST048': [0, 0, 0],
#  'ST049': [0, 0, 0],
#  'ST050': [0, 0, 0],
#  'ST051': [0, 0, 0],
#  'ST052': [0, 0, 0],
#  'ST053': [0, 0, 0],
#  'ST054': [0, 0, 0],
#  'ST055': [0, 0, 0],
#  'ST056': [0, 0, 0],
#  'ST057': [0, 0, 0],
#  'ST058': [0, 0, 0],
#  'ST059': [0, 0, 0],
#  'ST060': [0, 0, 0],
#  'ST061': [0, 0, 0],
#  'ST062': [0, 0, 0],
#  'ST063': [0, 0, 0],
#  'ST064': [0, 0, 0],
#  'ST065': [0, 0, 0],
#  'ST066': [0, 0, 0],
#  'ST067': [0, 0, 0],
#  'ST068': [0, 0, 0],
#  'ST069': [0, 0, 0],
#  'ST070': [0, 0, 0],
#  'ST071': [0, 0, 0],
#  'ST072': [0, 0, 0],
#  'ST073': [0, 0, 0],
#  'ST074': [0, 0, 0],
#  'ST075': [0, 0, 0],
#  'ST076': [0, 0, 0],
#  'ST077': [0, 0, 0],
#  'ST078': [0, 0, 0]}

# %%
dr115 = df.query('Point == "R115"')[['Group','X', 'Y', 'Z']].copy()
dr115['d'] = np.sqrt(dr115['X']**2 + dr115['Y']**2 + dr115['Z'])

r115_m = dr115.mean(numeric_only=True)
r115_sd = dr115.std(numeric_only=True)

print(r115_m)
print(r115_sd)

dr115

x = r115_m.X-dr115['X'].iloc[0]
y = r115_m.Y-dr115['Y'].iloc[0]
z = r115_m.Z-dr115['Z'].iloc[0]
st['ST001'] = [x,y,z]

v = st['ST001'][0], st['ST001'][1], st['ST001'][2]
u = dr115['X'].iloc[0], dr115['Y'].iloc[0], dr115['Z'].iloc[0]

np.add(u,v)
dr115['X'].iloc[0] = dr115['X'].iloc[0] + v[0]
dr115['Y'].iloc[0] = dr115['Y'].iloc[0] + v[1]
dr115['Z'].iloc[0] = dr115['Z'].iloc[0] + v[2]
dr115['d'] = np.sqrt(dr115['X']**2 + dr115['Y']**2 + dr115['Z'])

d2c_m = dr115.mean(numeric_only=True)
d2c_sd = dr115.std(numeric_only=True)
print('--- updated ---')
print(d2c_m)
print(d2c_sd)
# Out:
# X    153678.968256
# Y      4794.852543
# Z      2246.168910
# d    153753.758137
# dtype: float64
# X    0.062386
# Y    0.324797
# Z    0.091292
# d    0.052282
# dtype: float64
# --- updated ---
# X    153678.955528
# Y      4794.921554
# Z      2246.145894
# d    153753.747568
# dtype: float64
# X    0.051741
# Y    0.264149
# Z    0.066039
# d    0.043539
# dtype: float64
# C:\Users\alelen\AppData\Local\Temp\ipykernel_13612\3842771411.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr115['X'].iloc[0] = dr115['X'].iloc[0] + v[0]
# C:\Users\alelen\AppData\Local\Temp\ipykernel_13612\3842771411.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr115['Y'].iloc[0] = dr115['Y'].iloc[0] + v[1]
# C:\Users\alelen\AppData\Local\Temp\ipykernel_13612\3842771411.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dr115['Z'].iloc[0] = dr115['Z'].iloc[0] + v[2]

# %%
dfix1 = df[['Point', 'Group', 'X', 'Y', 'Z']].query('Point == "L0611"')

def distance(x,y,z): return np.sqrt(x**2+y**2+z**2)
distance(dfix1['X'], dfix1['Y'], dfix1['Z'])

dfix1['d'] = distance(dfix1['X'], dfix1['Y'], dfix1['Z'])

dfix1[['X', 'Y', 'Z', 'd']]
u1 = dfix1[['X', 'Y', 'Z', 'd']].mean()
sig1 = dfix1[['X', 'Y', 'Z', 'd']].std()

for i,val in enumerate(dfix1['Group']):
    st[val] = [u1.X-dfix1['X'].iloc[i],u1.Y-dfix1['Y'].iloc[i],u1.Z-dfix1['Z'].iloc[i]]
dfix1
st

df_comp = df.copy()
df_comp
for i,val in enumerate(dfix1['Group']):
    dfix1[['Group', 'X','Y','Z']].query("Group == '@val' ")


dfix1_a = dfix1.copy()

for i in range(len(dfix1)):
    name = dfix1['Group'].iloc[i]
    y = st[name]
    print(name,y)
    dfix1_a[['X', 'Y', 'Z']] = np.add(dfix1[['X', 'Y', 'Z']].iloc[i],y)
    z = np.add(dfix1[['X', 'Y', 'Z']].iloc[i],y)-dfix1[['X', 'Y', 'Z']].iloc[i]
    print(z)

dfix1_a['d'] = distance(dfix1_a['X'], dfix1_a['Y'], dfix1_a['Z'])
u1_a = dfix1_a[['X', 'Y', 'Z', 'd']].mean()
sig1_a = dfix1_a[['X', 'Y', 'Z', 'd']].std()

print("---- Before ----")
# print(u1)
print(sig1)

print("---- After ---- ")
# print(u1_a)
print(sig1_a)

dfix1_a[['X', 'Y', 'Z', 'd']] - dfix1[['X', 'Y', 'Z', 'd']]

dfix1
dfix1_a
# Out:
# ST55 [-0.43742108283913694, 1.1953152325322662, -0.6040093637129758]
# X   -0.437421
# Y    1.195315
# Z   -0.604009
# Name: 1293, dtype: float64
# ST56 [-0.4749238194490317, 1.2268241826550366, -0.638289484923007]
# X   -0.474924
# Y    1.226824
# Z   -0.638289
# Name: 1307, dtype: float64
# ST57 [0.22253308846848086, -0.4263302969529832, -0.22200927201629383]
# X    0.222533
# Y   -0.426330
# Z   -0.222009
# Name: 1329, dtype: float64
# ST58 [-1.824285392591264, -2.0720712358152014, 0.8521446570084663]
# X   -1.824285
# Y   -2.072071
# Z    0.852145
# Name: 1343, dtype: float64
# ST59 [0.3768742487882264, -0.0781941173981977, 0.33745583858399186]
# X    0.376874
# Y   -0.078194
# Z    0.337456
# Name: 1354, dtype: float64
# ST60 [0.43076685594860464, 0.12224565957785671, 0.24266064129187725]
# X    0.430767
# Y    0.122246
# Z    0.242661
# Name: 1368, dtype: float64
# ST030 [0.5268456205667462, -0.07029398714803392, 0.0454108877456747]
# X    0.526846
# Y   -0.070294
# Z    0.045411
# Name: 1823, dtype: float64
# ST031 [0.5515249173913617, -0.03762905885014334, 0.0018727408751146868]
# X    0.551525
# Y   -0.037629
# Z    0.001873
# Name: 1844, dtype: float64
# ST032 [0.6280855638324283, 0.14013362140576646, -0.015236644860124215]
# X    0.628086
# Y    0.140134
# Z   -0.015237
# Name: 1861, dtype: float64
# ---- Before ----
# X    0.798300
# Y    0.965412
# Z    0.464050
# d    0.761738
# dtype: float64
# ---- After ----
# X    0.0
# Y    0.0
# Z    0.0
# d    0.0
# dtype: float64
#       Point  Group              X            Y             Z              d
# 1293  L0611   ST55  150266.624933  4929.038048  37696.634787  155001.258895
# 1307  L0611   ST56  150266.624933  4929.038048  37696.634787  155001.258895
# 1329  L0611   ST57  150266.624933  4929.038048  37696.634787  155001.258895
# 1343  L0611   ST58  150266.624933  4929.038048  37696.634787  155001.258895
# 1354  L0611   ST59  150266.624933  4929.038048  37696.634787  155001.258895
# 1368  L0611   ST60  150266.624933  4929.038048  37696.634787  155001.258895
# 1823  L0611  ST030  150266.624933  4929.038048  37696.634787  155001.258895
# 1844  L0611  ST031  150266.624933  4929.038048  37696.634787  155001.258895
# 1861  L0611  ST032  150266.624933  4929.038048  37696.634787  155001.258895

# %%
# for i in st:
    # print(i,st[i])

x = list(st.keys())[0]
df1 = df.query("Group == @x")
# st[x] = [7e+6, 7e+6, 7e+6]
df1.loc[:, ('X')] = np.add(df1['X'],st[x][0])
df1.loc[:, ('Y')] = np.add(df1['Y'],st[x][1])
df1.loc[:, ('Z')] = np.add(df1['Z'],st[x][2])

# df1

# %%
for i in st:
    df1.loc[:,('X', 'Y', 'Z')]= np.add(df1.loc[:,('X', 'Y', 'Z')], st[i])

df1
df1.loc[:, ('Point','X', 'Y', 'Z', '[U-x]', '[U-y]', '[U-z]')]
# Out:
#                    Point              X            Y             Z     [U-x]  \
# 0                   R115  153678.459159  4797.612974   2245.248266  0.022260
# 1                   R114  153694.993370  6443.406206   2243.108908  0.021723
# 2                   R110  149710.436046  4791.216083   2263.165891  0.031847
# 3                   R108  149709.195283  6099.913534   2256.235342  0.031386
# 4                   R001  156950.936828  6445.786388   2239.112140  0.013254
# 5                   R002  156956.129089  4799.305135   2244.431815  0.013894
# 6                   R010  160931.148814  5500.604740   2247.172209  0.013644
# 7                   R008  160935.976356  6444.693021   2246.387167  0.013656
# 8                   R009  161612.591789  6102.736314   2633.046406  0.016129
# 9                   R011  161609.312203  4801.236297   2640.472933  0.016838
# 10                  R018  169443.685015  5805.398871   1862.493681  0.034479
# 11                  R019  169443.286459  6453.435464   1861.436156  0.034539
# 12                  R014  164784.062548  6456.705908   -827.500646  0.023414
# 13                  R007  161402.711372  6452.659033  -2780.428926  0.020061
# 14                  R004  156882.192698  6324.997848  -3738.187330  0.022954
# 15                  R117  152899.283148  6451.368063  -4902.086853  0.034020
# 16                 F1201  149686.410689  5805.494602  -1518.684087  0.032209
# 17                 F1202  149864.969628  5805.513599  -1315.952609  0.031500
# 18                 F1203  151346.727880  5805.677471  -2065.155687  0.029200
# 19                 F1204  153004.538576  5805.837220  -2157.471320  0.025565
# 20  I-TR1-MAG-SM1B-01-F1  155672.198379  5824.276246  -2404.254343  0.020149
# 21                 F0101  157584.655764  5805.403188  -2422.203463  0.016258
# 22                 F0102  157637.913307  5805.291976  -2157.354725  0.015074
# 23                 F0103  159295.742923  5805.371069  -2065.178406  0.013495
# 24                 F0104  160777.566910  5805.288951  -1316.111962  0.013925
# 25                 F0105  160956.147256  5805.338252  -1518.841812  0.014921
# 26                 F0201  164876.531760  5805.890086    744.222492  0.022630
# 27                 F0202  164790.245299  5805.863741   1000.219038  0.022456
# 28                 F0203  166179.884349  5805.921015   1908.995668  0.026463
# 29                 F0204  167088.614068  5805.849656   3298.628148  0.030565
# 30                 F0205  167344.626553  5805.886893   3212.350417  0.031017
# 31                 U12F1  149400.172968  4620.355270    -31.778168  0.032083
# 32                 U12F2  149138.739043  4590.482862   -480.794039  0.033019
# 33                 U12F4  149407.312416  6137.160711    -21.781136  0.031468
# 34                 U12F5  149171.886749  6288.543888   -427.755817  0.032315
# 35                 U12F8  149332.815135  6114.845079    108.594621  0.031596
# 36                 U12F7  149325.461388  5454.164602    115.306785  0.031694
# 37                 U12F6  149331.728621  4882.550571    109.720500  0.031983
# 38                 U12F9  148911.083173  4556.821838    359.546503  0.033212
# 39                U12F14  147358.296074  6118.707945   1249.697947  0.036522
# 40                U12F11  147775.719638  4565.073719   1015.975036  0.036003
# 41                 U07F8  155627.410348  5912.160451  27584.632288  0.042558
#
#        [U-y]     [U-z]
# 0   0.026721  0.026549
# 1   0.026315  0.025961
# 2   0.045276  0.045121
# 3   0.045109  0.044764
# 4   0.012308  0.012918
# 5   0.013528  0.013700
# 6   0.012791  0.013277
# 7   0.012805  0.013287
# 8   0.016314  0.016220
# 9   0.017193  0.017049
# 10  0.051549  0.051372
# 11  0.051566  0.051416
# 12  0.029603  0.029276
# 13  0.020853  0.019313
# 14  0.023531  0.020473
# 15  0.039677  0.034809
# 16  0.045818  0.045156
# 17  0.044755  0.044203
# 18  0.038861  0.037727
# 19  0.031622  0.030324
# 20  0.021564  0.020261
# 21  0.016298  0.016066
# 22  0.015019  0.015308
# 23  0.013473  0.014538
# 24  0.013375  0.013980
# 25  0.014679  0.014949
# 26  0.029091  0.029094
# 27  0.028714  0.028701
# 28  0.035906  0.035676
# 29  0.041791  0.040791
# 30  0.042853  0.041932
# 31  0.046293  0.046474
# 32  0.047764  0.047841
# 33  0.046043  0.045980
# 34  0.047371  0.047220
# 35  0.046360  0.046319
# 36  0.046423  0.046417
# 37  0.046502  0.046620
# 38  0.048565  0.048817
# 39  0.055920  0.055883
# 40  0.054036  0.054267
# 41  0.053846  0.048379

# %%
import pandas as pd

i_df = pd.read_excel("C:/Users/alelen/Documents/Export Data/Instrument Transforms.xls", skiprows=36, header=None)
c = i_df.head(8).to_markdown(); print(c)
len(i_df)/7

i_df_org = pd.DataFrame(columns=['Station name', 'Measures', 'Scale factor', 'Position X', 'Position Y', 'Position Z', 'Rx', 'Ry', 'Rz'])

for i in range(0,len(i_df),7):
    name = i_df[0].iloc[0+i]
    meas = i_df[1].iloc[1+i]
    scale = i_df[1].iloc[2+i]
    px = i_df[1].iloc[4+i]
    py = i_df[2].iloc[4+i]
    pz = i_df[3].iloc[4+i]
    rx = i_df[1].iloc[6+i]
    ry = i_df[2].iloc[6+i]
    rz = i_df[3].iloc[6+i]

    i_df_org.loc[len(i_df_org)] = [name, meas, scale, px, py,pz, rx,ry,rz]

i_df_org.loc[:, ('Station name')] = 'ST' + i_df_org['Station name'].str.split('ST').str[1]

i_df_org
# Out:
# |    | 0                                     | 1          | 2         | 3       |
# |---:|:--------------------------------------|:-----------|:----------|:--------|
# |  0 | Transform                             | nan        | nan       | nan     |
# |    | 1.5 Gev Ring tunnel survey::0 - ST001 |            |           |         |
# |  1 | # Meas.                               | 82         | nan       | nan     |
# |  2 | Scale Factor                          | 1          | nan       | nan     |
# |  3 | Position                              | X          | Y         | Z       |
# |  4 | (mm)                                  | 158878.545 | 5970.3347 | 677.337 |
# |  5 | Rotation                              | Rx         | Ry        | Rz      |
# |  6 | (deg)                                 | -89.9992   | -38.9375  | 0.0032  |
# |  7 | Transform                             | nan        | nan       | nan     |
# |    | 1.5 Gev Ring tunnel survey::1 - ST002 |            |           |         |
#     Station name  Measures  Scale factor   Position X  Position Y  Position Z  \
# 0          ST001        82             1  158878.5450   5970.3347    677.3370
# 1          ST002        64             1  162880.0330   5975.8091    832.1280
# 2          ST003        62             1  164507.5445   5979.2017   3513.4338
# 3          ST004        49             1  166998.2756   5977.2459   6725.6802
# 4          ST005        62             1  168381.8692   5980.2714   9644.0899
# ..           ...       ...           ...          ...         ...         ...
# 119         ST86        26             1  172926.4893   6220.5487  21203.7370
# 120        ST100        20             1  170816.2532   5943.3323  31346.4193
# 121        ST101        28             1  175403.4776   5941.5553  30906.4692
# 122        ST102        28             1  176963.0921   5946.3693  13423.8784
# 123        ST103        48             1  181653.5238   5759.3186   6383.2277
#
#           Rx       Ry        Rz
# 0   -89.9992 -38.9375    0.0032
# 1   -89.9978 -68.5317    0.0018
# 2    89.9989 -44.2707 -179.9955
# 3   -89.9989  57.8478    0.0049
# 4   -89.9994   2.3958    0.0041
# ..       ...      ...       ...
# 119  89.9980 -24.3871  179.9985
# 120  89.9987  52.8034  179.9928
# 121 -89.9974  37.3072   -0.0043
# 122  89.9985  15.7606  179.9952
# 123  90.0008   8.9050  179.9946
#
# [124 rows x 9 columns]

# %%
s = "Transform\n1.5 Gev Ring survey::36 - ST86"	
s1 = "Transform\n1.5 Gev Ring survey::38 - ST101"
s = s[s.rfind('ST')+0:]
print(s)
s1 = s1[s1.rfind('ST')+0:]
print(s1)

i_df_org.loc[:, ('Station name')] = 'ST' + i_df_org['Station name'].str.split('ST').str[1]
i_df_org
# Out:
# ST86
# ST101
#     Station name  Measures  Scale factor   Position X  Position Y  Position Z  \
# 0          ST001        82             1  158878.5450   5970.3347    677.3370
# 1          ST002        64             1  162880.0330   5975.8091    832.1280
# 2          ST003        62             1  164507.5445   5979.2017   3513.4338
# 3          ST004        49             1  166998.2756   5977.2459   6725.6802
# 4          ST005        62             1  168381.8692   5980.2714   9644.0899
# ..           ...       ...           ...          ...         ...         ...
# 119         ST86        26             1  172926.4893   6220.5487  21203.7370
# 120        ST100        20             1  170816.2532   5943.3323  31346.4193
# 121        ST101        28             1  175403.4776   5941.5553  30906.4692
# 122        ST102        28             1  176963.0921   5946.3693  13423.8784
# 123        ST103        48             1  181653.5238   5759.3186   6383.2277
#
#           Rx       Ry        Rz
# 0   -89.9992 -38.9375    0.0032
# 1   -89.9978 -68.5317    0.0018
# 2    89.9989 -44.2707 -179.9955
# 3   -89.9989  57.8478    0.0049
# 4   -89.9994   2.3958    0.0041
# ..       ...      ...       ...
# 119  89.9980 -24.3871  179.9985
# 120  89.9987  52.8034  179.9928
# 121 -89.9974  37.3072   -0.0043
# 122  89.9985  15.7606  179.9952
# 123  90.0008   8.9050  179.9946
#
# [124 rows x 9 columns]

# %%
import numpy as np
df.columns.values
df['d'] = np.nan
df['m_distance'] = np.nan
df['m_x'] = np.nan
df['m_y'] = np.nan
df['m_z'] = np.nan

def distance3(dx_f, dy_f, dz_f):
    return dx_f, dy_f, dz_f

i_df_org
df
d1 = df.loc[:, ('Group', 'X', 'Y','Z','d', 'm_x', 'm_y', 'm_z', 'm_distance')].copy()

for j,i in enumerate(i_df_org['Station name']):
    i_loc = d1.query("Group == @i").index
    d1.loc[i_loc, 'm_x'] = i_df_org.loc[j, 'Position X'] - d1.loc[i_loc, 'X']
    d1.loc[i_loc, 'm_y'] = i_df_org.loc[j, 'Position Y'] - d1.loc[i_loc, 'Y']
    d1.loc[i_loc, 'm_z'] = i_df_org.loc[j, 'Position Z'] - d1.loc[i_loc, 'Z']

d1.loc[:, ('d')] = np.sqrt(d1.loc[:, ('X')]**2 + d1.loc[:, ('Y')]**2 + d1.loc[:, ('Z')]**2)
d1.loc[:, ('m_distance')] = np.sqrt(d1.loc[:, ('m_x')]**2 + d1.loc[:, ('m_y')]**2 + d1.loc[:, ('m_z')]**2)

# d1.query("Group == 'ST001'") = 
i_loc = d1.query("Group == 'ST001'").index
# d1.loc[i_loc, 'm_x'] = 0
d1.query("Group == 'ST001'")
# x = d1.to_markdown(); print(x)

print(d1['m_distance'].mean())
d1['m_distance'].std()
d1

p = df.to_markdown(); print(p)
# Out:
# 6971.724450828585
# |      | Collection                 | Group                 | Point                |      X |       Y |           Z |   Planar offset |   Radial offset | 8   | 9   | 10   | 11   | 12   | 13   | 14   | 15   |      [U-x] |      [U-y] |      [U-z] |   [U-mag] | Timestamp         | 21   | Last Face   | Tracker            | Reflector             | Target                  | RMS Error             |   Temperature |   Pressure |   Humidity | Mode                                           | Status                                                    | Type measurement   | 33           | Level compensation 1         | Level compensation 2   | Level compensation 3                  |    [Var(x)] |   [CoVar(xy)] |   [CoVar(xz)] |   [CoVar(xy)] |    [Var(y)] |   [CoVar(yz)] |   [CoVar(xz)] |   [CoVar(yz)] |    [Var(z)] |   d |   Measurement Distance |   m_distance |   m_x |   m_y |   m_z |
Measure Time Discrete Point Standard Pt. To SA | emScon FAST Measurement Mode Used Laser Status: Ready     | Front/Back=True    | Separate Obs | std components: 1 = 0.001112 | 2 = 0.000810           | 3 = 0.000150 mm Level Compensation ON | 0.00019821  |   1.15696e-05 |   9.29412e-06 |   1.15696e-05 | 0.000193047 |   7.44893e-06 |   9.29412e-06 |   7.44893e-06 | 0.000189758 | nan |                    nan |          nan |   nan |   nan |   nan |
# | 2356 | 1.5 Gev Beamlines survey   | ST078                 | L0740                | 123963 | 4313.3  |  27079.1    |           19.05 |           19.05 |     |     |      |      |      |      |      |      | 0.0141785  | 0.014388   | 0.0147069  | 0.0249867 | 07/25/23 10:40:24 |      | Face 2:     | Leica AT403 394315 | Reflector 'RRR 1.5in' | Target 'SMR: RRR 1.5in' | RMS Error 0.001117 mm |          21.8 |      991.3 |       59.9 | Measure Time Discrete Point Standard Pt. To SA | emScon FAST Measurement Mode Used Laser Status: Ready     | Front/Back=True    | Separate Obs | std components: 1 = 0.000361 | 2 = 0.000229           | 3 = 0.000050 mm Level Compensation ON | 0.000201029 |  -1.27756e-06 |  -2.01379e-06 |  -1.27756e-06 | 0.000207016 |   9.849e-06   |  -2.01379e-06 |   9.849e-06   | 0.000216292 | nan |                    nan |          nan |   nan |   nan |   nan |
# | 2357 | 1.5 Gev Beamlines survey   | ST078                 | L0736                | 124044 | 4309.9  |  28563      |           19.05 |           19.05 |     |     |      |      |      |      |      |      | 0.00927879 | 0.0114171  | 0.0100642  | 0.0178251 | 07/25/23 10:41:22 |      | Face 2:     | Leica AT403 394315 | Reflector 'RRR 1.5in' | Target 'SMR: RRR 1.5in' | RMS Error 0.002309 mm |          21.8 |      991.3 |       59.8 | Measure Time Discrete Point Standard Pt. To SA | emScon FAST Measurement Mode Used Laser Status: Ready     | Front/Back=True    | Separate Obs | std components: 1 = 0.001723 | 2 = 0.000718           | 3 = 0.000500 mm Level Compensation ON | 8.6096e-05  |  -1.21053e-05 |  -7.52311e-06 |  -1.21053e-05 | 0.000130349 |   2.94256e-05 |  -7.52311e-06 |   2.94256e-05 | 0.000101288 | nan |                    nan |          nan |   nan |   nan |   nan |

# %%
rank_df = pd.read_csv("C:/Users/alelen/Documents/Export Data/USMN Report_1.xls", skiprows=143)

# i_df = pd.read_excel("C:/Users/alelen/Documents/Export Data/Instrument Transforms.xls", skiprows=36, header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 rank_df = pd.read_csv("C:/Users/alelen/Documents/Export Data/USMN Report_1.xls", skiprows=143)
#       3 # i_df = pd.read_excel("C:/Users/alelen/Documents/Export Data/Instrument Transforms.xls", skiprows=36, header=None)
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:814, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:875, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File c:\Users\alelen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:2029, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 1620, saw 7

# %%
len(df)
18*4+10-(1.5*18)
# Out:
# 55.0
